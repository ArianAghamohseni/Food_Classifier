# %%
# ___________________________ Episode 2 _______________________________________________

# %%
tr_ac11 = [48.83, 62.66, 66.40, 68.96, 70.53, 71.94, 72.62, 73.58, 74.24, 75.11]
tr_loss11 = [1.920, 1.293, 1.149, 1.055, 1.002, 0.925, 0.908, 0.892, 0.849, 0.831]
val_ac11 = [64.31, 67.46, 69.59, 70.96, 71.64, 72.51, 74.28, 74.60, 75.19, 75.47]
val_loss11 = [0.643, 0.645,0.696, 0.710 , 0.716, 0.725, 0.728, 0.746, 0.720, 0.755]

# %%
tr_ac12 = [66.84, 75.01, 78.44, 81.39, 83.29, 84.47, 85.82, 86.60, 88.26, 88.61]
tr_loss12 = [1.176, 0.868, 0.747, 0.643, 0.587, 0.538, 0.488, 0.455, 0.416, 0.384]
val_ac12 = [75.92, 77.74, 80.29, 83.16, 85.03, 85.98, 86.57, 87.71, 88.39, 89.17]
val_loss12 = [0.811, 0.746, 0.670, 0.592, 0.534, 0.488, 0.462, 0.431, 0.407, 0.393]

# %%
tr_ac13 = [87.26, 89.04, 89.79, 90.52, 91.57, 91.87, 92.73, 93.63, 93.98, 94.14]
tr_loss13 = [0.432, 0.377, 0.346, 0.322, 0.289, 0.274, 0.246, 0.220, 0.210, 0.200]
val_ac13 = [89.12, 89.90, 89.76, 90.21, 91.08, 92.03, 92.08, 92.22, 91.99, 92.17]
val_loss13 = [0.376, 0.371, 0.366, 0.342, 0.323, 0.315, 0.315, 0.305, 0.306, 0.300]

# %%
tr_ac14 = [93.96, 94.55, 95.05]
tr_loss14 = [0.201, 0.191, 0.171]
val_ac14 = [91.62, 91.99, 92.26]
val_loss14 = [0.301, 0.301, 0.297]

# %%
import matplotlib.pyplot as plt

# Combined Data
epochs_11 = list(range(len(tr_ac11)))
epochs_12 = list(range(len(tr_ac11), len(tr_ac11) + len(tr_ac12)))
epochs_13 = list(range(len(tr_ac11) + len(tr_ac12), len(tr_ac11) + len(tr_ac12) + len(tr_ac13)))
epochs_14 = list(range(len(tr_ac11) + len(tr_ac12) + len(tr_ac13), len(tr_ac11) + len(tr_ac12) + len(tr_ac13) + len(tr_ac14)))

# Continuous data for accuracy
combined_epochs = epochs_11 + epochs_12 + epochs_13 + epochs_14
combined_tr_ac = tr_ac11 + tr_ac12 + tr_ac13 + tr_ac14
combined_val_ac = val_ac11 + val_ac12 + val_ac13 + val_ac14
combined_tr_loss = tr_loss11 + tr_loss12 + tr_loss13 + tr_loss14
combined_val_loss = val_loss11 + val_loss12 + val_loss13 + val_loss14

# Create a custom label list for x-ticks
labels = [''] * len(combined_epochs)

# Calculate middle indices
middle_11 = len(epochs_11) // 2
middle_12 = len(epochs_11) + len(epochs_12) // 2
middle_13 = len(epochs_11) + len(epochs_12) + len(epochs_13) // 2
middle_14 = len(epochs_11) + len(epochs_12) + len(epochs_13) + len(epochs_14) // 2

# Set labels only at middle points
labels[middle_11] = 'No Trainable Layer'
labels[middle_12] = '100 Layer Non-Trainable'
labels[middle_13] = '50 Layer Non-Trainable'
labels[middle_14] = 'All layer Trainable'

# Plot Accuracy
plt.figure(figsize=(25, 8))

plt.subplot(1, 2, 1)
plt.plot(combined_epochs, combined_tr_ac, color='green', label='Train Accuracy', marker='o', linestyle='-', linewidth=2)
plt.plot(combined_epochs, combined_val_ac, color='red', label='Validation Accuracy', marker='x', linestyle='--', linewidth=2)
plt.xlabel('Epochs', fontsize=14, fontname='Times New Roman')
plt.ylabel('Acc', fontsize=14, fontname='Times New Roman')
plt.title('Accuracy Plot', fontsize=16, fontname='Times New Roman')
plt.legend(loc='upper left')
plt.grid(True)

# Add vertical lines for each interval
plt.axvline(x=len(epochs_11) - 1, color='black', linestyle='--', marker='o')
plt.axvline(x=len(epochs_11) + len(epochs_12) - 1, color='black', linestyle='--', marker='o')
plt.axvline(x=len(epochs_11) + len(epochs_12) + len(epochs_13) - 1, color='black', linestyle='--', marker='o')

# Plot Loss
plt.subplot(1, 2, 2)
plt.plot(combined_epochs, combined_tr_loss, color='green', label='Train Loss', marker='o', linestyle='-', linewidth=2)
plt.plot(combined_epochs, combined_val_loss, color='red', label='Validation Loss', marker='x', linestyle='--', linewidth=2)
plt.xlabel('Epochs', fontsize=14, fontname='Times New Roman')
plt.ylabel('Loss', fontsize=14, fontname='Times New Roman')
plt.title('Loss Plot', fontsize=16, fontname='Times New Roman')
plt.legend(loc='lower left')
plt.grid(True)

# Add vertical lines for each interval
plt.axvline(x=len(epochs_11) - 1, color='black', linestyle='--', marker='o')
plt.axvline(x=len(epochs_11) + len(epochs_12) - 1, color='black', linestyle='--', marker='o')
plt.axvline(x=len(epochs_11) + len(epochs_12) + len(epochs_13) - 1, color='black', linestyle='--', marker='o')

# Set custom x-tick labels
plt.subplot(1, 2, 1)
plt.xticks(ticks=combined_epochs, labels=labels, rotation=0, fontsize=14, fontname='Times New Roman')

plt.subplot(1, 2, 2)
plt.xticks(ticks=combined_epochs, labels=labels, rotation=0, fontsize=14, fontname='Times New Roman')

plt.tight_layout()
plt.show()

# %%
# ___________________________ Episode 3 _______________________________________________

# %%
tr_ac21 = [68.30, 67.90, 69.31, 68.71, 69.31, 69.05, 69.44, 69.40, 69.75, 69.90, 69.38, 69.73, 70.50, 69.88, 70.54]
tr_loss21 = [1.302, 1.279, 1.258, 1.257, 1.207, 1.243, 1.217, 1.226, 1.206, 1.197, 1.192, 1.167, 1.162, 1.181, 1.175]
val_ac21 = [69.23, 69.38, 69.52, 69.74, 69.82, 70.04, 70.33, 70.40, 70.55, 70.62, 70.70, 70.84, 70.77, 70.92, 70.99]
val_loss21 = [1.238, 1.219, 1.202, 1.188, 1.176, 1.165, 1.155, 1.146, 1.139, 1.132, 1.126, 1.121, 1.115, 1.111, 1.106]

# %%
tr_ac22 = [69.20, 71.69, 73.58, 74.28, 75.85, 77.37, 77.79, 78.58, 79.50, 80.34, 81.33, 81.46, 82.14, 82.28, 83.13]
tr_loss22 = [1.169, 0.999, 0.906, 0.856, 0.802, 0.744, 0.725, 0.696, 0.660, 0.629, 0.611, 0.604, 0.579, 0.564, 0.535]
val_ac22 = [73.85, 74.14, 75.38, 75.97, 76.56, 76.56, 76.41, 76.63, 76.85, 77.29, 77.44, 77.73, 77.44, 78.39, 78.46]
val_loss22 = [0.982, 0.944, 0.910, 0.889, 0.865, 0.843, 0.833, 0.816, 0.808, 0.793, 0.792, 0.784, 0.777, 0.768, 0.753]

# %%
tr_ac23 = [83.88, 84.88, 85.73, 85.93, 86.09, 86.64, 87.38, 87.63, 89.19, 88.66]
tr_loss23 = [0.5298, 0.4830, 0.4617, 0.4525, 0.4550, 0.4229, 0.4045, 0.3981, 0.3586, 0.3601]
val_ac23 = [79.27, 79.19, 79.34, 79.49, 79.78, 79.56, 79.56, 80.15, 80.81, 80.29]
val_loss23 = [0.7415, 0.7424, 0.7540, 0.7497, 0.7475, 0.7395, 0.7519, 0.7488, 0.7465, 0.7502]

# %%
# Combined Data
epochs_21 = list(range(len(tr_ac21)))
epochs_22 = list(range(len(tr_ac21), len(tr_ac21) + len(tr_ac22)))
epochs_23 = list(range(len(tr_ac21) + len(tr_ac22), len(tr_ac21) + len(tr_ac22) + len(tr_ac23)))

# Continuous data for accuracy
combined_epochs = epochs_21 + epochs_22 + epochs_23
combined_tr_ac = tr_ac21 + tr_ac22 + tr_ac23
combined_val_ac = val_ac21 + val_ac22 + val_ac23
combined_tr_loss = tr_loss21 + tr_loss22 + tr_loss23
combined_val_loss = val_loss21 + val_loss22 + val_loss23

# Create a custom label list for x-ticks
labels = [''] * len(combined_epochs)

# Calculate middle indices
middle_21 = len(epochs_21) // 2
middle_22 = len(epochs_21) + len(epochs_22) // 2
middle_23 = len(epochs_21) + len(epochs_22) + len(epochs_23) // 2

# Set labels only at middle points
labels[middle_21] = 'No Trainable Layer'
labels[middle_22] = '100 Layer Non-Trainable'
labels[middle_23] = 'All layer Trainable'

# Plot Accuracy
plt.figure(figsize=(25, 8))

plt.subplot(1, 2, 1)
plt.plot(combined_epochs, combined_tr_ac, color='green', label='Train Accuracy', marker='o', linestyle='-', linewidth=2)
plt.plot(combined_epochs, combined_val_ac, color='red', label='Validation Accuracy', marker='x', linestyle='--', linewidth=2)
plt.xlabel('Epochs', fontsize=14, fontname='Times New Roman')
plt.ylabel('Acc', fontsize=14, fontname='Times New Roman')
plt.title('Accuracy Plot', fontsize=16, fontname='Times New Roman')
plt.legend(loc='upper left')
plt.grid(True)

# Add vertical lines for each interval
plt.axvline(x=len(epochs_21) - 1, color='black', linestyle='--', marker='o')
plt.axvline(x=len(epochs_21) + len(epochs_22) - 1, color='black', linestyle='--', marker='o')

# Plot Loss
plt.subplot(1, 2, 2)
plt.plot(combined_epochs, combined_tr_loss, color='green', label='Train Loss', marker='o', linestyle='-', linewidth=2)
plt.plot(combined_epochs, combined_val_loss, color='red', label='Validation Loss', marker='x', linestyle='--', linewidth=2)
plt.xlabel('Epochs', fontsize=14, fontname='Times New Roman')
plt.ylabel('Loss', fontsize=14, fontname='Times New Roman')
plt.title('Loss Plot', fontsize=16, fontname='Times New Roman')
plt.legend(loc='lower left')
plt.grid(True)

# Add vertical lines for each interval
plt.axvline(x=len(epochs_21) - 1, color='black', linestyle='--', marker='o')
plt.axvline(x=len(epochs_21) + len(epochs_22) - 1, color='black', linestyle='--', marker='o')

# Set custom x-tick labels
plt.subplot(1, 2, 1)
plt.xticks(ticks=combined_epochs, labels=labels, rotation=0, fontsize=14, fontname='Times New Roman')

plt.subplot(1, 2, 2)
plt.xticks(ticks=combined_epochs, labels=labels, rotation=0, fontsize=14, fontname='Times New Roman')

plt.tight_layout()
plt.show()

# %%
# ___________________________ Episode 4 _______________________________________________

# %%
tr_ac31 = [33.32, 65.97, 73.49, 76.95, 78.18, 79.42, 80.91, 81.46, 82.03, 82.23, 83.10, 83.34, 83.87, 83.85, 84.55]
tr_loss31 = [2.8371, 1.0050, 0.7902, 0.6928, 0.6364, 0.6013, 0.5625, 0.5420, 0.5200, 0.5217, 0.4945, 0.4805, 0.4682, 0.4710, 0.4458]
val_ac31 = [57.67, 73.10, 77.29, 78.72, 80.30, 80.22, 80.62, 81.41, 82.36, 82.44, 82.91, 83.15, 83.47, 83.54, 84.18]
val_loss31 = [1.1465, 0.8214, 0.6865, 0.6123, 0.5806, 0.5545, 0.5408, 0.5241, 0.5081, 0.5068, 0.4958, 0.4809, 0.4907, 0.4812, 0.4737]

# %%
tr_ac32 = [81.78, 84.61, 86.80, 87.40, 88.05, 89.45, 90.09, 90.50, 90.92]
tr_loss32 = [0.5217, 0.4481, 0.4036, 0.3769, 0.3500, 0.3153, 0.2988, 0.2875, 0.2658]
val_ac32 = [82.00, 84.02, 84.26, 85.60, 86.31, 86.16, 87.42, 87.74, 88.21]
val_loss32 = [0.5091, 0.4801, 0.4601, 0.4260, 0.3978, 0.3747, 0.3622, 0.3500, 0.3431]

# %%
# Combine Data
epochs_31 = list(range(len(tr_ac31)))
epochs_32 = list(range(len(tr_ac31), len(tr_ac31) + len(tr_ac32)))

# Continuous data for accuracy and loss
combined_epochs = epochs_31 + epochs_32
combined_tr_ac = tr_ac31 + tr_ac32
combined_val_ac = val_ac31 + val_ac32
combined_tr_loss = tr_loss31 + tr_loss32
combined_val_loss = val_loss31 + val_loss32

# Create a custom label list for x-ticks
labels = [''] * len(combined_epochs)

# Calculate middle indices
middle_31 = len(epochs_31) // 2
middle_32 = len(epochs_31) + len(epochs_32) // 2

# Set labels only at middle points
labels[middle_31] = 'No Trainable Layer'
labels[middle_32] = '100 Layer Non-Trainable'

# Plot Accuracy
plt.figure(figsize=(25, 8))

plt.subplot(1, 2, 1)
plt.plot(combined_epochs, combined_tr_ac, color='green', label='Train Accuracy', marker='o', linestyle='-', linewidth=2)
plt.plot(combined_epochs, combined_val_ac, color='red', label='Validation Accuracy', marker='x', linestyle='--', linewidth=2)
plt.xlabel('Epochs', fontsize=14, fontname='Times New Roman')
plt.ylabel('Acc', fontsize=14, fontname='Times New Roman')
plt.title('Accuracy Plot', fontsize=16, fontname='Times New Roman')
plt.legend(loc='upper left')
plt.grid(True)

# Add vertical lines for each interval
plt.axvline(x=len(epochs_31) - 1, color='black', linestyle='--', marker='o')
plt.axvline(x=len(epochs_31) + len(epochs_32) - 1, color='black', linestyle='--', marker='o')

# Plot Loss
plt.subplot(1, 2, 2)
plt.plot(combined_epochs, combined_tr_loss, color='green', label='Train Loss', marker='o', linestyle='-', linewidth=2)
plt.plot(combined_epochs, combined_val_loss, color='red', label='Validation Loss', marker='x', linestyle='--', linewidth=2)
plt.xlabel('Epochs', fontsize=14, fontname='Times New Roman')
plt.ylabel('Loss', fontsize=14, fontname='Times New Roman')
plt.title('Loss Plot', fontsize=16, fontname='Times New Roman')
plt.legend(loc='lower left')
plt.grid(True)

# Add vertical lines for each interval
plt.axvline(x=len(epochs_31) - 1, color='black', linestyle='--', marker='o')
plt.axvline(x=len(epochs_31) + len(epochs_32) - 1, color='black', linestyle='--', marker='o')

# Set custom x-tick labels
plt.subplot(1, 2, 1)
plt.xticks(ticks=combined_epochs, labels=labels, rotation=0, fontsize=14, fontname='Times New Roman')

plt.subplot(1, 2, 2)
plt.xticks(ticks=combined_epochs, labels=labels, rotation=0, fontsize=14, fontname='Times New Roman')

plt.tight_layout()
plt.show()

# %%
# ___________________________ Episode 5 _______________________________________________

# %%
tr_ac41 = [85.68, 87.23, 87.63, 88.04, 88.97, 89.43, 89.62, 90.16, 90.57, 91.07]
tr_loss41 = [0.4576, 0.4103, 0.3931, 0.3710, 0.3483, 0.3419, 0.3229, 0.3116, 0.2970, 0.2839]
val_ac41 = [86.03, 86.95, 87.20, 87.59, 87.99, 88.20, 88.49, 88.32, 88.22, 88.51]
val_loss41 = [0.4661, 0.4396, 0.4311, 0.4250, 0.4110, 0.4091, 0.4018, 0.4077, 0.4029, 0.40041]

# %%
tr_ac42 = [92.17, 92.40, 92.46, 92.83, 92.86, 92.77, 93.01, 93.06, 93.14, 93.22]
tr_loss42 = [0.3025, 0.2969, 0.2875, 0.2700, 0.2686, 0.2753, 0.2707, 0.2659, 0.2608, 0.2530]
val_ac42 = [86.47, 86.78, 87.07, 87.26, 87.30, 87.43, 87.53, 87.57, 87.61, 87.59]
val_loss42 = [0.6614, 0.6448, 0.6335, 0.6254, 0.6182, 0.6127, 0.6084, 0.6046, 0.6020, 0.5994]

# %%
tr_ac43 = [91.23, 91.42, 92.01, 92.17, 92.44]
tr_loss43 = [0.2799, 0.2743, 0.2503, 0.2473, 0.2420]
val_ac43 = [88.65, 88.47, 88.57, 88.55, 88.86]
val_loss43 = [0.4099, 0.4015, 0.4006, 0.4022, 0.4013]

# %%
# Combined Data
epochs_41 = list(range(len(tr_ac41)))
epochs_42 = list(range(len(tr_ac41), len(tr_ac41) + len(tr_ac42)))
epochs_43 = list(range(len(tr_ac41) + len(tr_ac42), len(tr_ac41) + len(tr_ac42) + len(tr_ac43)))

# Continuous data for accuracy
combined_epochs = epochs_41 + epochs_42 + epochs_43
combined_tr_ac = tr_ac41 + tr_ac42 + tr_ac43
combined_val_ac = val_ac41 + val_ac42 + val_ac43
combined_tr_loss = tr_loss41 + tr_loss42 + tr_loss43
combined_val_loss = val_loss41 + val_loss42 + val_loss43

# Create a custom label list for x-ticks
labels = [''] * len(combined_epochs)

# Calculate middle indices
middle_41 = len(epochs_41) // 2
middle_42 = len(epochs_41) + len(epochs_42) // 2
middle_43 = len(epochs_41) + len(epochs_42) + len(epochs_43) // 2

# Set labels only at middle points
labels[middle_41] = '100 Layer Non-Trainable'
labels[middle_42] = 'All Layer Trainable & Dropout is 0.2 lower'
labels[middle_43] = 'All Layer Trainable & Dropout is 0.1 lower'

# Plot Accuracy
plt.figure(figsize=(25, 8))

plt.subplot(1, 2, 1)
plt.plot(combined_epochs, combined_tr_ac, color='green', label='Train Accuracy', marker='o', linestyle='-', linewidth=2)
plt.plot(combined_epochs, combined_val_ac, color='red', label='Validation Accuracy', marker='x', linestyle='--', linewidth=2)
plt.xlabel('Epochs', fontsize=14, fontname='Times New Roman')
plt.ylabel('Acc', fontsize=14, fontname='Times New Roman')
plt.title('Accuracy Plot', fontsize=16, fontname='Times New Roman')
plt.legend(loc='upper left')
plt.grid(True)

# Add vertical lines for each interval
plt.axvline(x=len(epochs_41) - 1, color='black', linestyle='--', marker='o')
plt.axvline(x=len(epochs_41) + len(epochs_42) - 1, color='black', linestyle='--', marker='o')

# Plot Loss
plt.subplot(1, 2, 2)
plt.plot(combined_epochs, combined_tr_loss, color='green', label='Train Loss', marker='o', linestyle='-', linewidth=2)
plt.plot(combined_epochs, combined_val_loss, color='red', label='Validation Loss', marker='x', linestyle='--', linewidth=2)
plt.xlabel('Epochs', fontsize=14, fontname='Times New Roman')
plt.ylabel('Loss', fontsize=14, fontname='Times New Roman')
plt.title('Loss Plot', fontsize=16, fontname='Times New Roman')
plt.legend(loc='lower left')
plt.grid(True)

# Add vertical lines for each interval
plt.axvline(x=len(epochs_41) - 1, color='black', linestyle='--', marker='o')
plt.axvline(x=len(epochs_41) + len(epochs_42) - 1, color='black', linestyle='--', marker='o')

# Set custom x-tick labels
plt.subplot(1, 2, 1)
plt.xticks(ticks=combined_epochs, labels=labels, rotation=0, fontsize=12, fontname='Times New Roman')

plt.subplot(1, 2, 2)
plt.xticks(ticks=combined_epochs, labels=labels, rotation=0, fontsize=12, fontname='Times New Roman')

plt.tight_layout()
plt.show()

# %%
# ___________________________ Episode 6 _______________________________________________

# %%
tr_ac51 = [97.17, 97.10, 96.98]
tr_loss51 = [0.0984, 0.0974, 0.0971]
val_ac51 = [89.75, 89.80, 89.46]
val_loss51 = [0.3984, 0.3988, 0.4042]

# %%
tr_ac52 = [88.60, 89.49, 89.74, 89.68, 89.66, 89.97, 89.98, 90.35, 90.69, 90.74, 90.53, 90.64, 90.36, 90.12, 90.44]
tr_loss52 = [0.3779, 0.3448, 0.3420, 0.3325, 0.3331, 0.3260, 0.3201, 0.3160, 0.2992, 0.2976, 0.3038, 0.3014, 0.3125, 0.3118, 0.3084]
val_ac52 = [89.30, 89.32, 89.17, 89.13, 89.05, 89.32, 89.40, 89.55, 89.55, 89.61, 89.57, 89.59, 89.59, 89.61, 89.61]
val_loss52 = [0.3997, 0.4032, 0.4116, 0.4148, 0.4100, 0.4048, 0.4008, 0.3978, 0.3981, 0.3962, 0.3959, 0.3960, 0.3958, 0.3960, 0.3958]

# %%
# Combined Data
epochs_51 = list(range(len(tr_ac51)))
epochs_52 = list(range(len(tr_ac51), len(tr_ac51) + len(tr_ac52)))

# Continuous data for accuracy and loss
combined_epochs = epochs_51 + epochs_52
combined_tr_ac = tr_ac51 + tr_ac52
combined_val_ac = val_ac51 + val_ac52
combined_tr_loss = tr_loss51 + tr_loss52
combined_val_loss = val_loss51 + val_loss52

# Create a custom label list for x-ticks
labels = [''] * len(combined_epochs)

# Calculate middle indices
middle_51 = len(epochs_51) // 2
middle_52 = len(epochs_51) + len(epochs_52) // 2

# Set labels only at middle points
labels[middle_51] = 'Model 1'
labels[middle_52] = 'Model 2'

# Plot Accuracy
plt.figure(figsize=(25, 8))

plt.subplot(1, 2, 1)
plt.plot(combined_epochs, combined_tr_ac, color='green', label='Train Accuracy', marker='o', linestyle='-', linewidth=2)
plt.plot(combined_epochs, combined_val_ac, color='red', label='Validation Accuracy', marker='x', linestyle='--', linewidth=2)
plt.xlabel('Epochs', fontsize=14, fontname='Times New Roman')
plt.ylabel('Accuracy (%)', fontsize=14, fontname='Times New Roman')
plt.title('Accuracy Plot', fontsize=16, fontname='Times New Roman')
plt.legend(loc='upper left')
plt.grid(True)

# Add vertical lines for each interval
plt.axvline(x=len(epochs_51) - 1, color='black', linestyle='--', marker='o')
plt.axvline(x=len(epochs_51) + len(epochs_52) - 1, color='black', linestyle='--', marker='o')

# Plot Loss
plt.subplot(1, 2, 2)
plt.plot(combined_epochs, combined_tr_loss, color='green', label='Train Loss', marker='o', linestyle='-', linewidth=2)
plt.plot(combined_epochs, combined_val_loss, color='red', label='Validation Loss', marker='x', linestyle='--', linewidth=2)
plt.xlabel('Epochs', fontsize=14, fontname='Times New Roman')
plt.ylabel('Loss', fontsize=14, fontname='Times New Roman')
plt.title('Loss Plot', fontsize=16, fontname='Times New Roman')
plt.legend(loc='lower left')
plt.grid(True)

# Add vertical lines for each interval
plt.axvline(x=len(epochs_51) - 1, color='black', linestyle='--', marker='o')
plt.axvline(x=len(epochs_51) + len(epochs_52) - 1, color='black', linestyle='--', marker='o')

# Set custom x-tick labels
plt.subplot(1, 2, 1)
plt.xticks(ticks=combined_epochs, labels=labels, rotation=0, fontsize=14, fontname='Times New Roman')

plt.subplot(1, 2, 2)
plt.xticks(ticks=combined_epochs, labels=labels, rotation=0, fontsize=14, fontname='Times New Roman')

plt.tight_layout()
plt.show()
